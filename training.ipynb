# %%
import mass_sims
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Now Training One Layer Models
# Layer: conv1.weight | Number of Parameters: 81
# Layer: conv1.bias | Number of Parameters: 3
# Layer: fc.weight | Number of Parameters: 7680
# Layer: fc.bias | Number of Parameters: 10
# Total trainable parameters: 7774
# Training model: conv_config=(3, 3, 3, 1, 1, 1)
# Epoch 1, Loss: 1.776, Accuracy: 37.70%
# Epoch 2, Loss: 1.558, Accuracy: 45.53%
# Epoch 3, Loss: 1.490, Accuracy: 47.60%
# Epoch 4, Loss: 1.459, Accuracy: 48.51%
# Epoch 5, Loss: 1.437, Accuracy: 49.11%
# Finished Training
# Testing model...
# Average test loss: 1.4631, Accuracy: 4822/10000 (48.22%)
# Layer: conv1.weight | Number of Parameters: 162
# Layer: conv1.bias | Number of Parameters: 6
# Layer: fc.weight | Number of Parameters: 15360
# Layer: fc.bias | Number of Parameters: 10
# Total trainable parameters: 15538
# Training model: conv_config=(3, 6, 3, 1, 1, 1)
# ...

# %%
mass_sims
